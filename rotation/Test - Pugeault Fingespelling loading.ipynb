# %%
# %load_ext autoreload
# %autoreload 2
from datasets import get_data
# Out:
# /home/facuq/dev/exp/rotation/.env/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
(x_train, y_train), (x_test, y_test), input_shape,num_classes=get_data("pugeault")
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# Found binary version in /home/facuq/.keras/datasets/pugeault/pugeault_skip1_testsubjectsE_color.npz, loading...
# (52992, 32, 32, 1) (12782, 32, 32, 1) (12782, 32, 32, 25) (12782, 25, 25)

# %%
import matplotlib.pyplot as plt
print(x_train.dtype,x_train.min(),x_train.max(),x_train.mean())
plt.figure(dpi=300)
plt.imshow(y_train)
# Out:
# float64 0.0 0.996078431372549 0.3740180108021709

# %%
import numpy as np
a=np.load("pugeault_32x32_rgb.npz")

# %%
print(a.files)
# Out:
# ['x_train', 'x_test', 'y_train', 'y_test']

# %%
a["x_train"].shape
# Out:
# (52992, 32, 32, 1)
