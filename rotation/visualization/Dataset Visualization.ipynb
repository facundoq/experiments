# %%
import matplotlib.pyplot as plt
# %load_ext autoreload
# %autoreload 2
plt.rcParams['image.cmap'] = 'gray'
import sys
sys.path.append("../")

# %%
import datasets
import numpy as np
import data.pugeault as pugeault

dataset="mnist"
(x_train, y_train), (x_test, y_test), input_shape,num_classes = datasets.get_data(dataset)

#x_train, x_test, y_train, y_test, img_channels, img_rows, img_cols = pugeault.load_data(skip=1)


print('x_train shape:', x_train.shape,x_train.dtype)
print('y_train shape:', y_train.shape,y_train.dtype)
print('x_test shape:', x_test.shape,x_test.dtype)
print('y_test shape:', y_test.shape,y_test.dtype)

print("x_train mean",np.mean(x_train))
print("x_test mean",np.mean(x_test))

print("y_train mean",np.mean(y_train))
print("y_test mean",np.mean(y_test))
# Out:
# Using TensorFlow backend.
# /home/facundo/.python/lib/python3.6/importlib/_bootstrap.py:205: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)
# x_train shape: (60000, 28, 28, 1) uint8
# y_train shape: (60000, 10) float64
# x_test shape: (10000, 28, 28, 1) uint8
# y_test shape: (10000, 10) float64
# x_train mean 33.3184214498
# x_test mean 33.7912244898
# y_train mean 0.1
# y_test mean 0.1

# %%
print('x_train shape:', x_train.shape,x_train.dtype)
print('y_train shape:', y_train.shape,y_train.dtype)
print('x_test shape:', x_test.shape,x_test.dtype)
print('y_test shape:', y_test.shape,y_test.dtype)

# %%
import matplotlib.pyplot as plt
n=x_train.shape[0]
for i in range(0,n,5000):
    image=x_train[i,:,:,:].squeeze()
    print(y_train[i,:])
    plt.imshow(image)
    plt.show()

# %%
import experiment
show_n=8
print("rotated")
experiment.visualize(x_train,y_train,show_n,rotated=True)
print("normal")
experiment.visualize(x_train,y_train,show_n,rotated=False)
# Out:
# rotated
# (8,)
# normal
# (8,)
