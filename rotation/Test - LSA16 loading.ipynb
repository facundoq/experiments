# %%
# %load_ext autoreload
# %autoreload 2
from datasets import get_data
# Out:
# /home/facuq/dev/exp/rotation/.env/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
(x_train, y_train), (x_test, y_test), input_shape,num_classes=get_data("lsa16")
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# Creating folder /home/facuq/.keras/datasets/lsa16...
# Creating folder /home/facuq/.keras/datasets/lsa16/lsa32x32_nr_rgb_black_background...
# Downloading lsa16 version=lsa32x32_nr_rgb_black_background to folder /home/facuq/.keras/datasets/lsa16/lsa32x32_nr_rgb_black_background/lsa32x32_nr_rgb_black_background.zip ...
# Downloading data from http://facundoq.github.io/unlp/lsa16/data/lsa32x32_nr_rgb_black_background.zip
# 663552/655994 [==============================] - 1s 1us/step
# Extracting images...
# Loading images from /home/facuq/.keras/datasets/lsa16/lsa32x32_nr_rgb_black_background/images
# /home/facuq/dev/exp/rotation/.env/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# (720, 32, 32, 3) (80, 32, 32, 3) (720, 16) (80, 16)

# %%
import matplotlib.pyplot as plt
print(x_train.dtype,x_train.min(),x_train.max(),x_train.mean())
plt.figure(dpi=300)
plt.imshow(y_train)
# Out:
# float32 0.0 0.000833333 0.000244547
