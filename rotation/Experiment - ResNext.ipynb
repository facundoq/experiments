# %%
import matplotlib.pyplot as plt
# %load_ext autoreload
# %autoreload 2
plt.rcParams['image.cmap'] = 'gray'
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import keras

import os
import datasets
import models
dataset="pugeault"
(x_train, y_train), (x_test, y_test), input_shape,num_classes = datasets.get_data(dataset)


print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# Downloading/extracting/recoding dataset...
# Loading images from /home/facundo/.keras/datasets/pugeault/dataset5
# /home/facundo/.python/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# Saving binary version of dataset to /home/facundo/.keras/datasets/pugeault/pugeault_skip1_testsubjectsE_color.npz
# x_train shape: (52992, 32, 32, 1)
# 52992 train samples
# 12782 test samples

# %%
cardinality=32
bottleneck_filters=64
initial_filters=64
lr=0.001
model = models.residual_network(input_shape,num_classes,cardinality,bottleneck_filters,initial_filters)
model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.RMSprop(lr=lr),
              metrics=['accuracy'])
print(model.summary())
print(model.name)
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_6 (InputLayer)            (None, 32, 32, 1)    0
# __________________________________________________________________________________________________
# conv2d_1546 (Conv2D)            (None, 32, 32, 64)   640         input_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 32, 32, 64)   256         conv2d_1546[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 32, 32, 64)   0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv2d_1547 (Conv2D)            (None, 32, 32, 64)   4160        activation_6[0][0]
# __________________________________________________________________________________________________
# lambda_1441 (Lambda)            (None, 32, 32, 2)    0           conv2d_1547[0][0]
# __________________________________________________________________________________________________
# lambda_1442 (Lambda)            (None, 32, 32, 2)    0           conv2d_1547[0][0]
# __________________________________________________________________________________________________
# lambda_1443 (Lambda)            (None, 32, 32, 2)    0           conv2d_1547[0][0]
# __________________________________________________________________________________________________
# lambda_1444 (Lambda)            (None, 32, 32, 2)    0           conv2d_1547[0][0]
# __________________________________________________________________________________________________
# lambda_1445 (Lambda)            (None, 32, 32, 2)    0           conv2d_1547[0][0]
# __________________________________________________________________________________________________
# lambda_1446 (Lambda)            (None, 32, 32, 2)    0           conv2d_1547[0][0]
# __________________________________________________________________________________________________
# lambda_1447 (Lambda)            (None, 32, 32, 2)    0           conv2d_1547[0][0]
# __________________________________________________________________________________________________
# lambda_1448 (Lambda)            (None, 32, 32, 2)    0           conv2d_1547[0][0]
# __________________________________________________________________________________________________
# lambda_1449 (Lambda)            (None, 32, 32, 2)    0           conv2d_1547[0][0]
# __________________________________________________________________________________________________
# lambda_1450 (Lambda)            (None, 32, 32, 2)    0           conv2d_1547[0][0]
# __________________________________________________________________________________________________
# lambda_1451 (Lambda)            (None, 32, 32, 2)    0           conv2d_1547[0][0]
# __________________________________________________________________________________________________
# lambda_1452 (Lambda)            (None, 32, 32, 2)    0           conv2d_1547[0][0]
# __________________________________________________________________________________________________
# lambda_1453 (Lambda)            (None, 32, 32, 2)    0           conv2d_1547[0][0]
# __________________________________________________________________________________________________
# lambda_1454 (Lambda)            (None, 32, 32, 2)    0           conv2d_1547[0][0]
# __________________________________________________________________________________________________
# lambda_1455 (Lambda)            (None, 32, 32, 2)    0           conv2d_1547[0][0]
# __________________________________________________________________________________________________
# lambda_1456 (Lambda)            (None, 32, 32, 2)    0           conv2d_1547[0][0]
# __________________________________________________________________________________________________
# lambda_1457 (Lambda)            (None, 32, 32, 2)    0           conv2d_1547[0][0]
# __________________________________________________________________________________________________
# lambda_1458 (Lambda)            (None, 32, 32, 2)    0           conv2d_1547[0][0]
# __________________________________________________________________________________________________
# lambda_1459 (Lambda)            (None, 32, 32, 2)    0           conv2d_1547[0][0]
# __________________________________________________________________________________________________
# lambda_1460 (Lambda)            (None, 32, 32, 2)    0           conv2d_1547[0][0]
# __________________________________________________________________________________________________
# lambda_1461 (Lambda)            (None, 32, 32, 2)    0           conv2d_1547[0][0]
# __________________________________________________________________________________________________
# lambda_1462 (Lambda)            (None, 32, 32, 2)    0           conv2d_1547[0][0]
# __________________________________________________________________________________________________
# lambda_1463 (Lambda)            (None, 32, 32, 2)    0           conv2d_1547[0][0]
# __________________________________________________________________________________________________
# lambda_1464 (Lambda)            (None, 32, 32, 2)    0           conv2d_1547[0][0]
# __________________________________________________________________________________________________
# lambda_1465 (Lambda)            (None, 32, 32, 2)    0           conv2d_1547[0][0]
# __________________________________________________________________________________________________
# lambda_1466 (Lambda)            (None, 32, 32, 2)    0           conv2d_1547[0][0]
# __________________________________________________________________________________________________
# lambda_1467 (Lambda)            (None, 32, 32, 2)    0           conv2d_1547[0][0]
# __________________________________________________________________________________________________
# lambda_1468 (Lambda)            (None, 32, 32, 2)    0           conv2d_1547[0][0]
# __________________________________________________________________________________________________
# lambda_1469 (Lambda)            (None, 32, 32, 2)    0           conv2d_1547[0][0]
# __________________________________________________________________________________________________
# lambda_1470 (Lambda)            (None, 32, 32, 2)    0           conv2d_1547[0][0]
# __________________________________________________________________________________________________
# lambda_1471 (Lambda)            (None, 32, 32, 2)    0           conv2d_1547[0][0]
# __________________________________________________________________________________________________
# lambda_1472 (Lambda)            (None, 32, 32, 2)    0           conv2d_1547[0][0]
# __________________________________________________________________________________________________
# conv2d_1548 (Conv2D)            (None, 32, 32, 2)    38          lambda_1441[0][0]
# __________________________________________________________________________________________________
# conv2d_1549 (Conv2D)            (None, 32, 32, 2)    38          lambda_1442[0][0]
# __________________________________________________________________________________________________
# conv2d_1550 (Conv2D)            (None, 32, 32, 2)    38          lambda_1443[0][0]
# __________________________________________________________________________________________________
# conv2d_1551 (Conv2D)            (None, 32, 32, 2)    38          lambda_1444[0][0]
# __________________________________________________________________________________________________
# conv2d_1552 (Conv2D)            (None, 32, 32, 2)    38          lambda_1445[0][0]
# __________________________________________________________________________________________________
# conv2d_1553 (Conv2D)            (None, 32, 32, 2)    38          lambda_1446[0][0]
# __________________________________________________________________________________________________
# conv2d_1554 (Conv2D)            (None, 32, 32, 2)    38          lambda_1447[0][0]
# __________________________________________________________________________________________________
# conv2d_1555 (Conv2D)            (None, 32, 32, 2)    38          lambda_1448[0][0]
# __________________________________________________________________________________________________
# conv2d_1556 (Conv2D)            (None, 32, 32, 2)    38          lambda_1449[0][0]
# __________________________________________________________________________________________________
# conv2d_1557 (Conv2D)            (None, 32, 32, 2)    38          lambda_1450[0][0]
# __________________________________________________________________________________________________
# conv2d_1558 (Conv2D)            (None, 32, 32, 2)    38          lambda_1451[0][0]
# __________________________________________________________________________________________________
# conv2d_1559 (Conv2D)            (None, 32, 32, 2)    38          lambda_1452[0][0]
# __________________________________________________________________________________________________
# conv2d_1560 (Conv2D)            (None, 32, 32, 2)    38          lambda_1453[0][0]
# __________________________________________________________________________________________________
# conv2d_1561 (Conv2D)            (None, 32, 32, 2)    38          lambda_1454[0][0]
# __________________________________________________________________________________________________
# conv2d_1562 (Conv2D)            (None, 32, 32, 2)    38          lambda_1455[0][0]
# __________________________________________________________________________________________________
# conv2d_1563 (Conv2D)            (None, 32, 32, 2)    38          lambda_1456[0][0]
# __________________________________________________________________________________________________
# conv2d_1564 (Conv2D)            (None, 32, 32, 2)    38          lambda_1457[0][0]
# __________________________________________________________________________________________________
# conv2d_1565 (Conv2D)            (None, 32, 32, 2)    38          lambda_1458[0][0]
# __________________________________________________________________________________________________
# conv2d_1566 (Conv2D)            (None, 32, 32, 2)    38          lambda_1459[0][0]
# __________________________________________________________________________________________________
# conv2d_1567 (Conv2D)            (None, 32, 32, 2)    38          lambda_1460[0][0]
# __________________________________________________________________________________________________
# conv2d_1568 (Conv2D)            (None, 32, 32, 2)    38          lambda_1461[0][0]
# __________________________________________________________________________________________________
# conv2d_1569 (Conv2D)            (None, 32, 32, 2)    38          lambda_1462[0][0]
# __________________________________________________________________________________________________
# conv2d_1570 (Conv2D)            (None, 32, 32, 2)    38          lambda_1463[0][0]
# __________________________________________________________________________________________________
# conv2d_1571 (Conv2D)            (None, 32, 32, 2)    38          lambda_1464[0][0]
# __________________________________________________________________________________________________
# conv2d_1572 (Conv2D)            (None, 32, 32, 2)    38          lambda_1465[0][0]
# __________________________________________________________________________________________________
# conv2d_1573 (Conv2D)            (None, 32, 32, 2)    38          lambda_1466[0][0]
# __________________________________________________________________________________________________
# conv2d_1574 (Conv2D)            (None, 32, 32, 2)    38          lambda_1467[0][0]
# __________________________________________________________________________________________________
# conv2d_1575 (Conv2D)            (None, 32, 32, 2)    38          lambda_1468[0][0]
# __________________________________________________________________________________________________
# conv2d_1576 (Conv2D)            (None, 32, 32, 2)    38          lambda_1469[0][0]
# __________________________________________________________________________________________________
# conv2d_1577 (Conv2D)            (None, 32, 32, 2)    38          lambda_1470[0][0]
# __________________________________________________________________________________________________
# conv2d_1578 (Conv2D)            (None, 32, 32, 2)    38          lambda_1471[0][0]
# __________________________________________________________________________________________________
# conv2d_1579 (Conv2D)            (None, 32, 32, 2)    38          lambda_1472[0][0]
# __________________________________________________________________________________________________
# concatenate_46 (Concatenate)    (None, 32, 32, 64)   0           conv2d_1548[0][0]
#                                                                  conv2d_1549[0][0]
#                                                                  conv2d_1550[0][0]
#                                                                  conv2d_1551[0][0]
#                                                                  conv2d_1552[0][0]
#                                                                  conv2d_1553[0][0]
#                                                                  conv2d_1554[0][0]
#                                                                  conv2d_1555[0][0]
#                                                                  conv2d_1556[0][0]
#                                                                  conv2d_1557[0][0]
#                                                                  conv2d_1558[0][0]
#                                                                  conv2d_1559[0][0]
#                                                                  conv2d_1560[0][0]
#                                                                  conv2d_1561[0][0]
#                                                                  conv2d_1562[0][0]
#                                                                  conv2d_1563[0][0]
#                                                                  conv2d_1564[0][0]
#                                                                  conv2d_1565[0][0]
#                                                                  conv2d_1566[0][0]
#                                                                  conv2d_1567[0][0]
#                                                                  conv2d_1568[0][0]
#                                                                  conv2d_1569[0][0]
#                                                                  conv2d_1570[0][0]
#                                                                  conv2d_1571[0][0]
#                                                                  conv2d_1572[0][0]
#                                                                  conv2d_1573[0][0]
#                                                                  conv2d_1574[0][0]
#                                                                  conv2d_1575[0][0]
#                                                                  conv2d_1576[0][0]
#                                                                  conv2d_1577[0][0]
#                                                                  conv2d_1578[0][0]
#                                                                  conv2d_1579[0][0]
# __________________________________________________________________________________________________
# conv2d_1580 (Conv2D)            (None, 32, 32, 64)   4160        concatenate_46[0][0]
# __________________________________________________________________________________________________
# add_46 (Add)                    (None, 32, 32, 64)   0           conv2d_1580[0][0]
#                                                                  activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 32, 32, 64)   256         add_46[0][0]
# __________________________________________________________________________________________________
# conv2d_1581 (Conv2D)            (None, 32, 32, 64)   4160        batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# lambda_1473 (Lambda)            (None, 32, 32, 2)    0           conv2d_1581[0][0]
# __________________________________________________________________________________________________
# lambda_1474 (Lambda)            (None, 32, 32, 2)    0           conv2d_1581[0][0]
# __________________________________________________________________________________________________
# lambda_1475 (Lambda)            (None, 32, 32, 2)    0           conv2d_1581[0][0]
# __________________________________________________________________________________________________
# lambda_1476 (Lambda)            (None, 32, 32, 2)    0           conv2d_1581[0][0]
# __________________________________________________________________________________________________
# lambda_1477 (Lambda)            (None, 32, 32, 2)    0           conv2d_1581[0][0]
# __________________________________________________________________________________________________
# lambda_1478 (Lambda)            (None, 32, 32, 2)    0           conv2d_1581[0][0]
# __________________________________________________________________________________________________
# lambda_1479 (Lambda)            (None, 32, 32, 2)    0           conv2d_1581[0][0]
# __________________________________________________________________________________________________
# lambda_1480 (Lambda)            (None, 32, 32, 2)    0           conv2d_1581[0][0]
# __________________________________________________________________________________________________
# lambda_1481 (Lambda)            (None, 32, 32, 2)    0           conv2d_1581[0][0]
# __________________________________________________________________________________________________
# lambda_1482 (Lambda)            (None, 32, 32, 2)    0           conv2d_1581[0][0]
# __________________________________________________________________________________________________
# lambda_1483 (Lambda)            (None, 32, 32, 2)    0           conv2d_1581[0][0]
# __________________________________________________________________________________________________
# lambda_1484 (Lambda)            (None, 32, 32, 2)    0           conv2d_1581[0][0]
# __________________________________________________________________________________________________
# lambda_1485 (Lambda)            (None, 32, 32, 2)    0           conv2d_1581[0][0]
# __________________________________________________________________________________________________
# lambda_1486 (Lambda)            (None, 32, 32, 2)    0           conv2d_1581[0][0]
# __________________________________________________________________________________________________
# lambda_1487 (Lambda)            (None, 32, 32, 2)    0           conv2d_1581[0][0]
# __________________________________________________________________________________________________
# lambda_1488 (Lambda)            (None, 32, 32, 2)    0           conv2d_1581[0][0]
# __________________________________________________________________________________________________
# lambda_1489 (Lambda)            (None, 32, 32, 2)    0           conv2d_1581[0][0]
# __________________________________________________________________________________________________
# lambda_1490 (Lambda)            (None, 32, 32, 2)    0           conv2d_1581[0][0]
# __________________________________________________________________________________________________
# lambda_1491 (Lambda)            (None, 32, 32, 2)    0           conv2d_1581[0][0]
# __________________________________________________________________________________________________
# lambda_1492 (Lambda)            (None, 32, 32, 2)    0           conv2d_1581[0][0]
# __________________________________________________________________________________________________
# lambda_1493 (Lambda)            (None, 32, 32, 2)    0           conv2d_1581[0][0]
# __________________________________________________________________________________________________
# lambda_1494 (Lambda)            (None, 32, 32, 2)    0           conv2d_1581[0][0]
# __________________________________________________________________________________________________
# lambda_1495 (Lambda)            (None, 32, 32, 2)    0           conv2d_1581[0][0]
# __________________________________________________________________________________________________
# lambda_1496 (Lambda)            (None, 32, 32, 2)    0           conv2d_1581[0][0]
# __________________________________________________________________________________________________
# lambda_1497 (Lambda)            (None, 32, 32, 2)    0           conv2d_1581[0][0]
# __________________________________________________________________________________________________
# lambda_1498 (Lambda)            (None, 32, 32, 2)    0           conv2d_1581[0][0]
# __________________________________________________________________________________________________
# lambda_1499 (Lambda)            (None, 32, 32, 2)    0           conv2d_1581[0][0]
# __________________________________________________________________________________________________
# lambda_1500 (Lambda)            (None, 32, 32, 2)    0           conv2d_1581[0][0]
# __________________________________________________________________________________________________
# lambda_1501 (Lambda)            (None, 32, 32, 2)    0           conv2d_1581[0][0]
# __________________________________________________________________________________________________
# lambda_1502 (Lambda)            (None, 32, 32, 2)    0           conv2d_1581[0][0]
# __________________________________________________________________________________________________
# lambda_1503 (Lambda)            (None, 32, 32, 2)    0           conv2d_1581[0][0]
# __________________________________________________________________________________________________
# lambda_1504 (Lambda)            (None, 32, 32, 2)    0           conv2d_1581[0][0]
# __________________________________________________________________________________________________
# conv2d_1582 (Conv2D)            (None, 32, 32, 2)    38          lambda_1473[0][0]
# __________________________________________________________________________________________________
# conv2d_1583 (Conv2D)            (None, 32, 32, 2)    38          lambda_1474[0][0]
# __________________________________________________________________________________________________
# conv2d_1584 (Conv2D)            (None, 32, 32, 2)    38          lambda_1475[0][0]
# __________________________________________________________________________________________________
# conv2d_1585 (Conv2D)            (None, 32, 32, 2)    38          lambda_1476[0][0]
# __________________________________________________________________________________________________
# conv2d_1586 (Conv2D)            (None, 32, 32, 2)    38          lambda_1477[0][0]
# __________________________________________________________________________________________________
# conv2d_1587 (Conv2D)            (None, 32, 32, 2)    38          lambda_1478[0][0]
# __________________________________________________________________________________________________
# conv2d_1588 (Conv2D)            (None, 32, 32, 2)    38          lambda_1479[0][0]
# __________________________________________________________________________________________________
# conv2d_1589 (Conv2D)            (None, 32, 32, 2)    38          lambda_1480[0][0]
# __________________________________________________________________________________________________
# conv2d_1590 (Conv2D)            (None, 32, 32, 2)    38          lambda_1481[0][0]
# __________________________________________________________________________________________________
# conv2d_1591 (Conv2D)            (None, 32, 32, 2)    38          lambda_1482[0][0]
# __________________________________________________________________________________________________
# conv2d_1592 (Conv2D)            (None, 32, 32, 2)    38          lambda_1483[0][0]
# __________________________________________________________________________________________________
# conv2d_1593 (Conv2D)            (None, 32, 32, 2)    38          lambda_1484[0][0]
# __________________________________________________________________________________________________
# conv2d_1594 (Conv2D)            (None, 32, 32, 2)    38          lambda_1485[0][0]
# __________________________________________________________________________________________________
# conv2d_1595 (Conv2D)            (None, 32, 32, 2)    38          lambda_1486[0][0]
# __________________________________________________________________________________________________
# conv2d_1596 (Conv2D)            (None, 32, 32, 2)    38          lambda_1487[0][0]
# __________________________________________________________________________________________________
# conv2d_1597 (Conv2D)            (None, 32, 32, 2)    38          lambda_1488[0][0]
# __________________________________________________________________________________________________
# conv2d_1598 (Conv2D)            (None, 32, 32, 2)    38          lambda_1489[0][0]
# __________________________________________________________________________________________________
# conv2d_1599 (Conv2D)            (None, 32, 32, 2)    38          lambda_1490[0][0]
# __________________________________________________________________________________________________
# conv2d_1600 (Conv2D)            (None, 32, 32, 2)    38          lambda_1491[0][0]
# __________________________________________________________________________________________________
# conv2d_1601 (Conv2D)            (None, 32, 32, 2)    38          lambda_1492[0][0]
# __________________________________________________________________________________________________
# conv2d_1602 (Conv2D)            (None, 32, 32, 2)    38          lambda_1493[0][0]
# __________________________________________________________________________________________________
# conv2d_1603 (Conv2D)            (None, 32, 32, 2)    38          lambda_1494[0][0]
# __________________________________________________________________________________________________
# conv2d_1604 (Conv2D)            (None, 32, 32, 2)    38          lambda_1495[0][0]
# __________________________________________________________________________________________________
# conv2d_1605 (Conv2D)            (None, 32, 32, 2)    38          lambda_1496[0][0]
# __________________________________________________________________________________________________
# conv2d_1606 (Conv2D)            (None, 32, 32, 2)    38          lambda_1497[0][0]
# __________________________________________________________________________________________________
# conv2d_1607 (Conv2D)            (None, 32, 32, 2)    38          lambda_1498[0][0]
# __________________________________________________________________________________________________
# conv2d_1608 (Conv2D)            (None, 32, 32, 2)    38          lambda_1499[0][0]
# __________________________________________________________________________________________________
# conv2d_1609 (Conv2D)            (None, 32, 32, 2)    38          lambda_1500[0][0]
# __________________________________________________________________________________________________
# conv2d_1610 (Conv2D)            (None, 32, 32, 2)    38          lambda_1501[0][0]
# __________________________________________________________________________________________________
# conv2d_1611 (Conv2D)            (None, 32, 32, 2)    38          lambda_1502[0][0]
# __________________________________________________________________________________________________
# conv2d_1612 (Conv2D)            (None, 32, 32, 2)    38          lambda_1503[0][0]
# __________________________________________________________________________________________________
# conv2d_1613 (Conv2D)            (None, 32, 32, 2)    38          lambda_1504[0][0]
# __________________________________________________________________________________________________
# concatenate_47 (Concatenate)    (None, 32, 32, 64)   0           conv2d_1582[0][0]
#                                                                  conv2d_1583[0][0]
#                                                                  conv2d_1584[0][0]
#                                                                  conv2d_1585[0][0]
#                                                                  conv2d_1586[0][0]
#                                                                  conv2d_1587[0][0]
#                                                                  conv2d_1588[0][0]
#                                                                  conv2d_1589[0][0]
#                                                                  conv2d_1590[0][0]
#                                                                  conv2d_1591[0][0]
#                                                                  conv2d_1592[0][0]
#                                                                  conv2d_1593[0][0]
#                                                                  conv2d_1594[0][0]
#                                                                  conv2d_1595[0][0]
#                                                                  conv2d_1596[0][0]
#                                                                  conv2d_1597[0][0]
#                                                                  conv2d_1598[0][0]
#                                                                  conv2d_1599[0][0]
#                                                                  conv2d_1600[0][0]
#                                                                  conv2d_1601[0][0]
#                                                                  conv2d_1602[0][0]
#                                                                  conv2d_1603[0][0]
#                                                                  conv2d_1604[0][0]
#                                                                  conv2d_1605[0][0]
#                                                                  conv2d_1606[0][0]
#                                                                  conv2d_1607[0][0]
#                                                                  conv2d_1608[0][0]
#                                                                  conv2d_1609[0][0]
#                                                                  conv2d_1610[0][0]
#                                                                  conv2d_1611[0][0]
#                                                                  conv2d_1612[0][0]
#                                                                  conv2d_1613[0][0]
# __________________________________________________________________________________________________
# conv2d_1614 (Conv2D)            (None, 32, 32, 64)   4160        concatenate_47[0][0]
# __________________________________________________________________________________________________
# add_47 (Add)                    (None, 32, 32, 64)   0           conv2d_1614[0][0]
#                                                                  batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 32, 32, 64)   256         add_47[0][0]
# __________________________________________________________________________________________________
# conv2d_1615 (Conv2D)            (None, 32, 32, 64)   4160        batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# lambda_1505 (Lambda)            (None, 32, 32, 2)    0           conv2d_1615[0][0]
# __________________________________________________________________________________________________
# lambda_1506 (Lambda)            (None, 32, 32, 2)    0           conv2d_1615[0][0]
# __________________________________________________________________________________________________
# lambda_1507 (Lambda)            (None, 32, 32, 2)    0           conv2d_1615[0][0]
# __________________________________________________________________________________________________
# lambda_1508 (Lambda)            (None, 32, 32, 2)    0           conv2d_1615[0][0]
# __________________________________________________________________________________________________
# lambda_1509 (Lambda)            (None, 32, 32, 2)    0           conv2d_1615[0][0]
# __________________________________________________________________________________________________
# lambda_1510 (Lambda)            (None, 32, 32, 2)    0           conv2d_1615[0][0]
# __________________________________________________________________________________________________
# lambda_1511 (Lambda)            (None, 32, 32, 2)    0           conv2d_1615[0][0]
# __________________________________________________________________________________________________
# lambda_1512 (Lambda)            (None, 32, 32, 2)    0           conv2d_1615[0][0]
# __________________________________________________________________________________________________
# lambda_1513 (Lambda)            (None, 32, 32, 2)    0           conv2d_1615[0][0]
# __________________________________________________________________________________________________
# lambda_1514 (Lambda)            (None, 32, 32, 2)    0           conv2d_1615[0][0]
# __________________________________________________________________________________________________
# lambda_1515 (Lambda)            (None, 32, 32, 2)    0           conv2d_1615[0][0]
# __________________________________________________________________________________________________
# lambda_1516 (Lambda)            (None, 32, 32, 2)    0           conv2d_1615[0][0]
# __________________________________________________________________________________________________
# lambda_1517 (Lambda)            (None, 32, 32, 2)    0           conv2d_1615[0][0]
# __________________________________________________________________________________________________
# lambda_1518 (Lambda)            (None, 32, 32, 2)    0           conv2d_1615[0][0]
# __________________________________________________________________________________________________
# lambda_1519 (Lambda)            (None, 32, 32, 2)    0           conv2d_1615[0][0]
# __________________________________________________________________________________________________
# lambda_1520 (Lambda)            (None, 32, 32, 2)    0           conv2d_1615[0][0]
# __________________________________________________________________________________________________
# lambda_1521 (Lambda)            (None, 32, 32, 2)    0           conv2d_1615[0][0]
# __________________________________________________________________________________________________
# lambda_1522 (Lambda)            (None, 32, 32, 2)    0           conv2d_1615[0][0]
# __________________________________________________________________________________________________
# lambda_1523 (Lambda)            (None, 32, 32, 2)    0           conv2d_1615[0][0]
# __________________________________________________________________________________________________
# lambda_1524 (Lambda)            (None, 32, 32, 2)    0           conv2d_1615[0][0]
# __________________________________________________________________________________________________
# lambda_1525 (Lambda)            (None, 32, 32, 2)    0           conv2d_1615[0][0]
# __________________________________________________________________________________________________
# lambda_1526 (Lambda)            (None, 32, 32, 2)    0           conv2d_1615[0][0]
# __________________________________________________________________________________________________
# lambda_1527 (Lambda)            (None, 32, 32, 2)    0           conv2d_1615[0][0]
# __________________________________________________________________________________________________
# lambda_1528 (Lambda)            (None, 32, 32, 2)    0           conv2d_1615[0][0]
# __________________________________________________________________________________________________
# lambda_1529 (Lambda)            (None, 32, 32, 2)    0           conv2d_1615[0][0]
# __________________________________________________________________________________________________
# lambda_1530 (Lambda)            (None, 32, 32, 2)    0           conv2d_1615[0][0]
# __________________________________________________________________________________________________
# lambda_1531 (Lambda)            (None, 32, 32, 2)    0           conv2d_1615[0][0]
# __________________________________________________________________________________________________
# lambda_1532 (Lambda)            (None, 32, 32, 2)    0           conv2d_1615[0][0]
# __________________________________________________________________________________________________
# lambda_1533 (Lambda)            (None, 32, 32, 2)    0           conv2d_1615[0][0]
# __________________________________________________________________________________________________
# lambda_1534 (Lambda)            (None, 32, 32, 2)    0           conv2d_1615[0][0]
# __________________________________________________________________________________________________
# lambda_1535 (Lambda)            (None, 32, 32, 2)    0           conv2d_1615[0][0]
# __________________________________________________________________________________________________
# lambda_1536 (Lambda)            (None, 32, 32, 2)    0           conv2d_1615[0][0]
# __________________________________________________________________________________________________
# conv2d_1616 (Conv2D)            (None, 32, 32, 2)    38          lambda_1505[0][0]
# __________________________________________________________________________________________________
# conv2d_1617 (Conv2D)            (None, 32, 32, 2)    38          lambda_1506[0][0]
# __________________________________________________________________________________________________
# conv2d_1618 (Conv2D)            (None, 32, 32, 2)    38          lambda_1507[0][0]
# __________________________________________________________________________________________________
# conv2d_1619 (Conv2D)            (None, 32, 32, 2)    38          lambda_1508[0][0]
# __________________________________________________________________________________________________
# conv2d_1620 (Conv2D)            (None, 32, 32, 2)    38          lambda_1509[0][0]
# __________________________________________________________________________________________________
# conv2d_1621 (Conv2D)            (None, 32, 32, 2)    38          lambda_1510[0][0]
# __________________________________________________________________________________________________
# conv2d_1622 (Conv2D)            (None, 32, 32, 2)    38          lambda_1511[0][0]
# __________________________________________________________________________________________________
# conv2d_1623 (Conv2D)            (None, 32, 32, 2)    38          lambda_1512[0][0]
# __________________________________________________________________________________________________
# conv2d_1624 (Conv2D)            (None, 32, 32, 2)    38          lambda_1513[0][0]
# __________________________________________________________________________________________________
# conv2d_1625 (Conv2D)            (None, 32, 32, 2)    38          lambda_1514[0][0]
# __________________________________________________________________________________________________
# conv2d_1626 (Conv2D)            (None, 32, 32, 2)    38          lambda_1515[0][0]
# __________________________________________________________________________________________________
# conv2d_1627 (Conv2D)            (None, 32, 32, 2)    38          lambda_1516[0][0]
# __________________________________________________________________________________________________
# conv2d_1628 (Conv2D)            (None, 32, 32, 2)    38          lambda_1517[0][0]
# __________________________________________________________________________________________________
# conv2d_1629 (Conv2D)            (None, 32, 32, 2)    38          lambda_1518[0][0]
# __________________________________________________________________________________________________
# conv2d_1630 (Conv2D)            (None, 32, 32, 2)    38          lambda_1519[0][0]
# __________________________________________________________________________________________________
# conv2d_1631 (Conv2D)            (None, 32, 32, 2)    38          lambda_1520[0][0]
# __________________________________________________________________________________________________
# conv2d_1632 (Conv2D)            (None, 32, 32, 2)    38          lambda_1521[0][0]
# __________________________________________________________________________________________________
# conv2d_1633 (Conv2D)            (None, 32, 32, 2)    38          lambda_1522[0][0]
# __________________________________________________________________________________________________
# conv2d_1634 (Conv2D)            (None, 32, 32, 2)    38          lambda_1523[0][0]
# __________________________________________________________________________________________________
# conv2d_1635 (Conv2D)            (None, 32, 32, 2)    38          lambda_1524[0][0]
# __________________________________________________________________________________________________
# conv2d_1636 (Conv2D)            (None, 32, 32, 2)    38          lambda_1525[0][0]
# __________________________________________________________________________________________________
# conv2d_1637 (Conv2D)            (None, 32, 32, 2)    38          lambda_1526[0][0]
# __________________________________________________________________________________________________
# conv2d_1638 (Conv2D)            (None, 32, 32, 2)    38          lambda_1527[0][0]
# __________________________________________________________________________________________________
# conv2d_1639 (Conv2D)            (None, 32, 32, 2)    38          lambda_1528[0][0]
# __________________________________________________________________________________________________
# conv2d_1640 (Conv2D)            (None, 32, 32, 2)    38          lambda_1529[0][0]
# __________________________________________________________________________________________________
# conv2d_1641 (Conv2D)            (None, 32, 32, 2)    38          lambda_1530[0][0]
# __________________________________________________________________________________________________
# conv2d_1642 (Conv2D)            (None, 32, 32, 2)    38          lambda_1531[0][0]
# __________________________________________________________________________________________________
# conv2d_1643 (Conv2D)            (None, 32, 32, 2)    38          lambda_1532[0][0]
# __________________________________________________________________________________________________
# conv2d_1644 (Conv2D)            (None, 32, 32, 2)    38          lambda_1533[0][0]
# __________________________________________________________________________________________________
# conv2d_1645 (Conv2D)            (None, 32, 32, 2)    38          lambda_1534[0][0]
# __________________________________________________________________________________________________
# conv2d_1646 (Conv2D)            (None, 32, 32, 2)    38          lambda_1535[0][0]
# __________________________________________________________________________________________________
# conv2d_1647 (Conv2D)            (None, 32, 32, 2)    38          lambda_1536[0][0]
# __________________________________________________________________________________________________
# concatenate_48 (Concatenate)    (None, 32, 32, 64)   0           conv2d_1616[0][0]
#                                                                  conv2d_1617[0][0]
#                                                                  conv2d_1618[0][0]
# ...
# __________________________________________________________________________________________________
# lambda_1704 (Lambda)            (None, 7, 7, 2)      0           conv2d_1821[0][0]
# __________________________________________________________________________________________________
# lambda_1705 (Lambda)            (None, 7, 7, 2)      0           conv2d_1821[0][0]
# __________________________________________________________________________________________________
# lambda_1706 (Lambda)            (None, 7, 7, 2)      0           conv2d_1821[0][0]
# __________________________________________________________________________________________________
# lambda_1707 (Lambda)            (None, 7, 7, 2)      0           conv2d_1821[0][0]
# __________________________________________________________________________________________________
# lambda_1708 (Lambda)            (None, 7, 7, 2)      0           conv2d_1821[0][0]
# __________________________________________________________________________________________________
# lambda_1709 (Lambda)            (None, 7, 7, 2)      0           conv2d_1821[0][0]
# __________________________________________________________________________________________________
# lambda_1710 (Lambda)            (None, 7, 7, 2)      0           conv2d_1821[0][0]
# __________________________________________________________________________________________________
# lambda_1711 (Lambda)            (None, 7, 7, 2)      0           conv2d_1821[0][0]
# __________________________________________________________________________________________________
# lambda_1712 (Lambda)            (None, 7, 7, 2)      0           conv2d_1821[0][0]
# __________________________________________________________________________________________________
# lambda_1713 (Lambda)            (None, 7, 7, 2)      0           conv2d_1821[0][0]
# __________________________________________________________________________________________________
# lambda_1714 (Lambda)            (None, 7, 7, 2)      0           conv2d_1821[0][0]
# __________________________________________________________________________________________________
# lambda_1715 (Lambda)            (None, 7, 7, 2)      0           conv2d_1821[0][0]
# __________________________________________________________________________________________________
# lambda_1716 (Lambda)            (None, 7, 7, 2)      0           conv2d_1821[0][0]
# __________________________________________________________________________________________________
# lambda_1717 (Lambda)            (None, 7, 7, 2)      0           conv2d_1821[0][0]
# __________________________________________________________________________________________________
# lambda_1718 (Lambda)            (None, 7, 7, 2)      0           conv2d_1821[0][0]
# __________________________________________________________________________________________________
# lambda_1719 (Lambda)            (None, 7, 7, 2)      0           conv2d_1821[0][0]
# __________________________________________________________________________________________________
# lambda_1720 (Lambda)            (None, 7, 7, 2)      0           conv2d_1821[0][0]
# __________________________________________________________________________________________________
# lambda_1721 (Lambda)            (None, 7, 7, 2)      0           conv2d_1821[0][0]
# __________________________________________________________________________________________________
# lambda_1722 (Lambda)            (None, 7, 7, 2)      0           conv2d_1821[0][0]
# __________________________________________________________________________________________________
# lambda_1723 (Lambda)            (None, 7, 7, 2)      0           conv2d_1821[0][0]
# __________________________________________________________________________________________________
# lambda_1724 (Lambda)            (None, 7, 7, 2)      0           conv2d_1821[0][0]
# __________________________________________________________________________________________________
# lambda_1725 (Lambda)            (None, 7, 7, 2)      0           conv2d_1821[0][0]
# __________________________________________________________________________________________________
# lambda_1726 (Lambda)            (None, 7, 7, 2)      0           conv2d_1821[0][0]
# __________________________________________________________________________________________________
# lambda_1727 (Lambda)            (None, 7, 7, 2)      0           conv2d_1821[0][0]
# __________________________________________________________________________________________________
# lambda_1728 (Lambda)            (None, 7, 7, 2)      0           conv2d_1821[0][0]
# __________________________________________________________________________________________________
# conv2d_1822 (Conv2D)            (None, 7, 7, 2)      38          lambda_1697[0][0]
# __________________________________________________________________________________________________
# conv2d_1823 (Conv2D)            (None, 7, 7, 2)      38          lambda_1698[0][0]
# __________________________________________________________________________________________________
# conv2d_1824 (Conv2D)            (None, 7, 7, 2)      38          lambda_1699[0][0]
# __________________________________________________________________________________________________
# conv2d_1825 (Conv2D)            (None, 7, 7, 2)      38          lambda_1700[0][0]
# __________________________________________________________________________________________________
# conv2d_1826 (Conv2D)            (None, 7, 7, 2)      38          lambda_1701[0][0]
# __________________________________________________________________________________________________
# conv2d_1827 (Conv2D)            (None, 7, 7, 2)      38          lambda_1702[0][0]
# __________________________________________________________________________________________________
# conv2d_1828 (Conv2D)            (None, 7, 7, 2)      38          lambda_1703[0][0]
# __________________________________________________________________________________________________
# conv2d_1829 (Conv2D)            (None, 7, 7, 2)      38          lambda_1704[0][0]
# __________________________________________________________________________________________________
# conv2d_1830 (Conv2D)            (None, 7, 7, 2)      38          lambda_1705[0][0]
# __________________________________________________________________________________________________
# conv2d_1831 (Conv2D)            (None, 7, 7, 2)      38          lambda_1706[0][0]
# __________________________________________________________________________________________________
# conv2d_1832 (Conv2D)            (None, 7, 7, 2)      38          lambda_1707[0][0]
# __________________________________________________________________________________________________
# conv2d_1833 (Conv2D)            (None, 7, 7, 2)      38          lambda_1708[0][0]
# __________________________________________________________________________________________________
# conv2d_1834 (Conv2D)            (None, 7, 7, 2)      38          lambda_1709[0][0]
# __________________________________________________________________________________________________
# conv2d_1835 (Conv2D)            (None, 7, 7, 2)      38          lambda_1710[0][0]
# __________________________________________________________________________________________________
# conv2d_1836 (Conv2D)            (None, 7, 7, 2)      38          lambda_1711[0][0]
# __________________________________________________________________________________________________
# conv2d_1837 (Conv2D)            (None, 7, 7, 2)      38          lambda_1712[0][0]
# __________________________________________________________________________________________________
# conv2d_1838 (Conv2D)            (None, 7, 7, 2)      38          lambda_1713[0][0]
# __________________________________________________________________________________________________
# conv2d_1839 (Conv2D)            (None, 7, 7, 2)      38          lambda_1714[0][0]
# __________________________________________________________________________________________________
# conv2d_1840 (Conv2D)            (None, 7, 7, 2)      38          lambda_1715[0][0]
# __________________________________________________________________________________________________
# conv2d_1841 (Conv2D)            (None, 7, 7, 2)      38          lambda_1716[0][0]
# __________________________________________________________________________________________________
# conv2d_1842 (Conv2D)            (None, 7, 7, 2)      38          lambda_1717[0][0]
# __________________________________________________________________________________________________
# conv2d_1843 (Conv2D)            (None, 7, 7, 2)      38          lambda_1718[0][0]
# __________________________________________________________________________________________________
# conv2d_1844 (Conv2D)            (None, 7, 7, 2)      38          lambda_1719[0][0]
# __________________________________________________________________________________________________
# conv2d_1845 (Conv2D)            (None, 7, 7, 2)      38          lambda_1720[0][0]
# __________________________________________________________________________________________________
# conv2d_1846 (Conv2D)            (None, 7, 7, 2)      38          lambda_1721[0][0]
# __________________________________________________________________________________________________
# conv2d_1847 (Conv2D)            (None, 7, 7, 2)      38          lambda_1722[0][0]
# __________________________________________________________________________________________________
# conv2d_1848 (Conv2D)            (None, 7, 7, 2)      38          lambda_1723[0][0]
# __________________________________________________________________________________________________
# conv2d_1849 (Conv2D)            (None, 7, 7, 2)      38          lambda_1724[0][0]
# __________________________________________________________________________________________________
# conv2d_1850 (Conv2D)            (None, 7, 7, 2)      38          lambda_1725[0][0]
# __________________________________________________________________________________________________
# conv2d_1851 (Conv2D)            (None, 7, 7, 2)      38          lambda_1726[0][0]
# __________________________________________________________________________________________________
# conv2d_1852 (Conv2D)            (None, 7, 7, 2)      38          lambda_1727[0][0]
# __________________________________________________________________________________________________
# conv2d_1853 (Conv2D)            (None, 7, 7, 2)      38          lambda_1728[0][0]
# __________________________________________________________________________________________________
# concatenate_54 (Concatenate)    (None, 7, 7, 64)     0           conv2d_1822[0][0]
#                                                                  conv2d_1823[0][0]
#                                                                  conv2d_1824[0][0]
#                                                                  conv2d_1825[0][0]
#                                                                  conv2d_1826[0][0]
#                                                                  conv2d_1827[0][0]
#                                                                  conv2d_1828[0][0]
#                                                                  conv2d_1829[0][0]
#                                                                  conv2d_1830[0][0]
#                                                                  conv2d_1831[0][0]
#                                                                  conv2d_1832[0][0]
#                                                                  conv2d_1833[0][0]
#                                                                  conv2d_1834[0][0]
#                                                                  conv2d_1835[0][0]
#                                                                  conv2d_1836[0][0]
#                                                                  conv2d_1837[0][0]
#                                                                  conv2d_1838[0][0]
#                                                                  conv2d_1839[0][0]
#                                                                  conv2d_1840[0][0]
#                                                                  conv2d_1841[0][0]
#                                                                  conv2d_1842[0][0]
#                                                                  conv2d_1843[0][0]
#                                                                  conv2d_1844[0][0]
#                                                                  conv2d_1845[0][0]
#                                                                  conv2d_1846[0][0]
#                                                                  conv2d_1847[0][0]
#                                                                  conv2d_1848[0][0]
#                                                                  conv2d_1849[0][0]
#                                                                  conv2d_1850[0][0]
#                                                                  conv2d_1851[0][0]
#                                                                  conv2d_1852[0][0]
#                                                                  conv2d_1853[0][0]
# __________________________________________________________________________________________________
# conv2d_1854 (Conv2D)            (None, 7, 7, 256)    16640       concatenate_54[0][0]
# __________________________________________________________________________________________________
# add_54 (Add)                    (None, 7, 7, 256)    0           conv2d_1854[0][0]
#                                                                  batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 7, 7, 256)    1024        add_54[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_6 (Glo (None, 256)          0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# fc2 (Dense)                     (None, 25)           6425        global_average_pooling2d_6[0][0]
# ==================================================================================================
# Total params: 566,617
# Trainable params: 563,801
# Non-trainable params: 2,816
# __________________________________________________________________________________________________
# None
# residual_network

# %%
rotated_model = models.residual_network(input_shape,num_classes,cardinality,bottleneck_filters,initial_filters)
rotated_model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.RMSprop(lr=lr),
              metrics=['accuracy'])
print(rotated_model.summary())
print(rotated_model.name)
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_7 (InputLayer)            (None, 32, 32, 1)    0
# __________________________________________________________________________________________________
# conv2d_1855 (Conv2D)            (None, 32, 32, 64)   640         input_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 32, 32, 64)   256         conv2d_1855[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 32, 32, 64)   0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# conv2d_1856 (Conv2D)            (None, 32, 32, 64)   4160        activation_7[0][0]
# __________________________________________________________________________________________________
# lambda_1729 (Lambda)            (None, 32, 32, 2)    0           conv2d_1856[0][0]
# __________________________________________________________________________________________________
# lambda_1730 (Lambda)            (None, 32, 32, 2)    0           conv2d_1856[0][0]
# __________________________________________________________________________________________________
# lambda_1731 (Lambda)            (None, 32, 32, 2)    0           conv2d_1856[0][0]
# __________________________________________________________________________________________________
# lambda_1732 (Lambda)            (None, 32, 32, 2)    0           conv2d_1856[0][0]
# __________________________________________________________________________________________________
# lambda_1733 (Lambda)            (None, 32, 32, 2)    0           conv2d_1856[0][0]
# __________________________________________________________________________________________________
# lambda_1734 (Lambda)            (None, 32, 32, 2)    0           conv2d_1856[0][0]
# __________________________________________________________________________________________________
# lambda_1735 (Lambda)            (None, 32, 32, 2)    0           conv2d_1856[0][0]
# __________________________________________________________________________________________________
# lambda_1736 (Lambda)            (None, 32, 32, 2)    0           conv2d_1856[0][0]
# __________________________________________________________________________________________________
# lambda_1737 (Lambda)            (None, 32, 32, 2)    0           conv2d_1856[0][0]
# __________________________________________________________________________________________________
# lambda_1738 (Lambda)            (None, 32, 32, 2)    0           conv2d_1856[0][0]
# __________________________________________________________________________________________________
# lambda_1739 (Lambda)            (None, 32, 32, 2)    0           conv2d_1856[0][0]
# __________________________________________________________________________________________________
# lambda_1740 (Lambda)            (None, 32, 32, 2)    0           conv2d_1856[0][0]
# __________________________________________________________________________________________________
# lambda_1741 (Lambda)            (None, 32, 32, 2)    0           conv2d_1856[0][0]
# __________________________________________________________________________________________________
# lambda_1742 (Lambda)            (None, 32, 32, 2)    0           conv2d_1856[0][0]
# __________________________________________________________________________________________________
# lambda_1743 (Lambda)            (None, 32, 32, 2)    0           conv2d_1856[0][0]
# __________________________________________________________________________________________________
# lambda_1744 (Lambda)            (None, 32, 32, 2)    0           conv2d_1856[0][0]
# __________________________________________________________________________________________________
# lambda_1745 (Lambda)            (None, 32, 32, 2)    0           conv2d_1856[0][0]
# __________________________________________________________________________________________________
# lambda_1746 (Lambda)            (None, 32, 32, 2)    0           conv2d_1856[0][0]
# __________________________________________________________________________________________________
# lambda_1747 (Lambda)            (None, 32, 32, 2)    0           conv2d_1856[0][0]
# __________________________________________________________________________________________________
# lambda_1748 (Lambda)            (None, 32, 32, 2)    0           conv2d_1856[0][0]
# __________________________________________________________________________________________________
# lambda_1749 (Lambda)            (None, 32, 32, 2)    0           conv2d_1856[0][0]
# __________________________________________________________________________________________________
# lambda_1750 (Lambda)            (None, 32, 32, 2)    0           conv2d_1856[0][0]
# __________________________________________________________________________________________________
# lambda_1751 (Lambda)            (None, 32, 32, 2)    0           conv2d_1856[0][0]
# __________________________________________________________________________________________________
# lambda_1752 (Lambda)            (None, 32, 32, 2)    0           conv2d_1856[0][0]
# __________________________________________________________________________________________________
# lambda_1753 (Lambda)            (None, 32, 32, 2)    0           conv2d_1856[0][0]
# __________________________________________________________________________________________________
# lambda_1754 (Lambda)            (None, 32, 32, 2)    0           conv2d_1856[0][0]
# __________________________________________________________________________________________________
# lambda_1755 (Lambda)            (None, 32, 32, 2)    0           conv2d_1856[0][0]
# __________________________________________________________________________________________________
# lambda_1756 (Lambda)            (None, 32, 32, 2)    0           conv2d_1856[0][0]
# __________________________________________________________________________________________________
# lambda_1757 (Lambda)            (None, 32, 32, 2)    0           conv2d_1856[0][0]
# __________________________________________________________________________________________________
# lambda_1758 (Lambda)            (None, 32, 32, 2)    0           conv2d_1856[0][0]
# __________________________________________________________________________________________________
# lambda_1759 (Lambda)            (None, 32, 32, 2)    0           conv2d_1856[0][0]
# __________________________________________________________________________________________________
# lambda_1760 (Lambda)            (None, 32, 32, 2)    0           conv2d_1856[0][0]
# __________________________________________________________________________________________________
# conv2d_1857 (Conv2D)            (None, 32, 32, 2)    38          lambda_1729[0][0]
# __________________________________________________________________________________________________
# conv2d_1858 (Conv2D)            (None, 32, 32, 2)    38          lambda_1730[0][0]
# __________________________________________________________________________________________________
# conv2d_1859 (Conv2D)            (None, 32, 32, 2)    38          lambda_1731[0][0]
# __________________________________________________________________________________________________
# conv2d_1860 (Conv2D)            (None, 32, 32, 2)    38          lambda_1732[0][0]
# __________________________________________________________________________________________________
# conv2d_1861 (Conv2D)            (None, 32, 32, 2)    38          lambda_1733[0][0]
# __________________________________________________________________________________________________
# conv2d_1862 (Conv2D)            (None, 32, 32, 2)    38          lambda_1734[0][0]
# __________________________________________________________________________________________________
# conv2d_1863 (Conv2D)            (None, 32, 32, 2)    38          lambda_1735[0][0]
# __________________________________________________________________________________________________
# conv2d_1864 (Conv2D)            (None, 32, 32, 2)    38          lambda_1736[0][0]
# __________________________________________________________________________________________________
# conv2d_1865 (Conv2D)            (None, 32, 32, 2)    38          lambda_1737[0][0]
# __________________________________________________________________________________________________
# conv2d_1866 (Conv2D)            (None, 32, 32, 2)    38          lambda_1738[0][0]
# __________________________________________________________________________________________________
# conv2d_1867 (Conv2D)            (None, 32, 32, 2)    38          lambda_1739[0][0]
# __________________________________________________________________________________________________
# conv2d_1868 (Conv2D)            (None, 32, 32, 2)    38          lambda_1740[0][0]
# __________________________________________________________________________________________________
# conv2d_1869 (Conv2D)            (None, 32, 32, 2)    38          lambda_1741[0][0]
# __________________________________________________________________________________________________
# conv2d_1870 (Conv2D)            (None, 32, 32, 2)    38          lambda_1742[0][0]
# __________________________________________________________________________________________________
# conv2d_1871 (Conv2D)            (None, 32, 32, 2)    38          lambda_1743[0][0]
# __________________________________________________________________________________________________
# conv2d_1872 (Conv2D)            (None, 32, 32, 2)    38          lambda_1744[0][0]
# __________________________________________________________________________________________________
# conv2d_1873 (Conv2D)            (None, 32, 32, 2)    38          lambda_1745[0][0]
# __________________________________________________________________________________________________
# conv2d_1874 (Conv2D)            (None, 32, 32, 2)    38          lambda_1746[0][0]
# __________________________________________________________________________________________________
# conv2d_1875 (Conv2D)            (None, 32, 32, 2)    38          lambda_1747[0][0]
# __________________________________________________________________________________________________
# conv2d_1876 (Conv2D)            (None, 32, 32, 2)    38          lambda_1748[0][0]
# __________________________________________________________________________________________________
# conv2d_1877 (Conv2D)            (None, 32, 32, 2)    38          lambda_1749[0][0]
# __________________________________________________________________________________________________
# conv2d_1878 (Conv2D)            (None, 32, 32, 2)    38          lambda_1750[0][0]
# __________________________________________________________________________________________________
# conv2d_1879 (Conv2D)            (None, 32, 32, 2)    38          lambda_1751[0][0]
# __________________________________________________________________________________________________
# conv2d_1880 (Conv2D)            (None, 32, 32, 2)    38          lambda_1752[0][0]
# __________________________________________________________________________________________________
# conv2d_1881 (Conv2D)            (None, 32, 32, 2)    38          lambda_1753[0][0]
# __________________________________________________________________________________________________
# conv2d_1882 (Conv2D)            (None, 32, 32, 2)    38          lambda_1754[0][0]
# __________________________________________________________________________________________________
# conv2d_1883 (Conv2D)            (None, 32, 32, 2)    38          lambda_1755[0][0]
# __________________________________________________________________________________________________
# conv2d_1884 (Conv2D)            (None, 32, 32, 2)    38          lambda_1756[0][0]
# __________________________________________________________________________________________________
# conv2d_1885 (Conv2D)            (None, 32, 32, 2)    38          lambda_1757[0][0]
# __________________________________________________________________________________________________
# conv2d_1886 (Conv2D)            (None, 32, 32, 2)    38          lambda_1758[0][0]
# __________________________________________________________________________________________________
# conv2d_1887 (Conv2D)            (None, 32, 32, 2)    38          lambda_1759[0][0]
# __________________________________________________________________________________________________
# conv2d_1888 (Conv2D)            (None, 32, 32, 2)    38          lambda_1760[0][0]
# __________________________________________________________________________________________________
# concatenate_55 (Concatenate)    (None, 32, 32, 64)   0           conv2d_1857[0][0]
#                                                                  conv2d_1858[0][0]
#                                                                  conv2d_1859[0][0]
#                                                                  conv2d_1860[0][0]
#                                                                  conv2d_1861[0][0]
#                                                                  conv2d_1862[0][0]
#                                                                  conv2d_1863[0][0]
#                                                                  conv2d_1864[0][0]
#                                                                  conv2d_1865[0][0]
#                                                                  conv2d_1866[0][0]
#                                                                  conv2d_1867[0][0]
#                                                                  conv2d_1868[0][0]
#                                                                  conv2d_1869[0][0]
#                                                                  conv2d_1870[0][0]
#                                                                  conv2d_1871[0][0]
#                                                                  conv2d_1872[0][0]
#                                                                  conv2d_1873[0][0]
#                                                                  conv2d_1874[0][0]
#                                                                  conv2d_1875[0][0]
#                                                                  conv2d_1876[0][0]
#                                                                  conv2d_1877[0][0]
#                                                                  conv2d_1878[0][0]
#                                                                  conv2d_1879[0][0]
#                                                                  conv2d_1880[0][0]
#                                                                  conv2d_1881[0][0]
#                                                                  conv2d_1882[0][0]
#                                                                  conv2d_1883[0][0]
#                                                                  conv2d_1884[0][0]
#                                                                  conv2d_1885[0][0]
#                                                                  conv2d_1886[0][0]
#                                                                  conv2d_1887[0][0]
#                                                                  conv2d_1888[0][0]
# __________________________________________________________________________________________________
# conv2d_1889 (Conv2D)            (None, 32, 32, 64)   4160        concatenate_55[0][0]
# __________________________________________________________________________________________________
# add_55 (Add)                    (None, 32, 32, 64)   0           conv2d_1889[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 32, 32, 64)   256         add_55[0][0]
# __________________________________________________________________________________________________
# conv2d_1890 (Conv2D)            (None, 32, 32, 64)   4160        batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# lambda_1761 (Lambda)            (None, 32, 32, 2)    0           conv2d_1890[0][0]
# __________________________________________________________________________________________________
# lambda_1762 (Lambda)            (None, 32, 32, 2)    0           conv2d_1890[0][0]
# __________________________________________________________________________________________________
# lambda_1763 (Lambda)            (None, 32, 32, 2)    0           conv2d_1890[0][0]
# __________________________________________________________________________________________________
# lambda_1764 (Lambda)            (None, 32, 32, 2)    0           conv2d_1890[0][0]
# __________________________________________________________________________________________________
# lambda_1765 (Lambda)            (None, 32, 32, 2)    0           conv2d_1890[0][0]
# __________________________________________________________________________________________________
# lambda_1766 (Lambda)            (None, 32, 32, 2)    0           conv2d_1890[0][0]
# __________________________________________________________________________________________________
# lambda_1767 (Lambda)            (None, 32, 32, 2)    0           conv2d_1890[0][0]
# __________________________________________________________________________________________________
# lambda_1768 (Lambda)            (None, 32, 32, 2)    0           conv2d_1890[0][0]
# __________________________________________________________________________________________________
# lambda_1769 (Lambda)            (None, 32, 32, 2)    0           conv2d_1890[0][0]
# __________________________________________________________________________________________________
# lambda_1770 (Lambda)            (None, 32, 32, 2)    0           conv2d_1890[0][0]
# __________________________________________________________________________________________________
# lambda_1771 (Lambda)            (None, 32, 32, 2)    0           conv2d_1890[0][0]
# __________________________________________________________________________________________________
# lambda_1772 (Lambda)            (None, 32, 32, 2)    0           conv2d_1890[0][0]
# __________________________________________________________________________________________________
# lambda_1773 (Lambda)            (None, 32, 32, 2)    0           conv2d_1890[0][0]
# __________________________________________________________________________________________________
# lambda_1774 (Lambda)            (None, 32, 32, 2)    0           conv2d_1890[0][0]
# __________________________________________________________________________________________________
# lambda_1775 (Lambda)            (None, 32, 32, 2)    0           conv2d_1890[0][0]
# __________________________________________________________________________________________________
# lambda_1776 (Lambda)            (None, 32, 32, 2)    0           conv2d_1890[0][0]
# __________________________________________________________________________________________________
# lambda_1777 (Lambda)            (None, 32, 32, 2)    0           conv2d_1890[0][0]
# __________________________________________________________________________________________________
# lambda_1778 (Lambda)            (None, 32, 32, 2)    0           conv2d_1890[0][0]
# __________________________________________________________________________________________________
# lambda_1779 (Lambda)            (None, 32, 32, 2)    0           conv2d_1890[0][0]
# __________________________________________________________________________________________________
# lambda_1780 (Lambda)            (None, 32, 32, 2)    0           conv2d_1890[0][0]
# __________________________________________________________________________________________________
# lambda_1781 (Lambda)            (None, 32, 32, 2)    0           conv2d_1890[0][0]
# __________________________________________________________________________________________________
# lambda_1782 (Lambda)            (None, 32, 32, 2)    0           conv2d_1890[0][0]
# __________________________________________________________________________________________________
# lambda_1783 (Lambda)            (None, 32, 32, 2)    0           conv2d_1890[0][0]
# __________________________________________________________________________________________________
# lambda_1784 (Lambda)            (None, 32, 32, 2)    0           conv2d_1890[0][0]
# __________________________________________________________________________________________________
# lambda_1785 (Lambda)            (None, 32, 32, 2)    0           conv2d_1890[0][0]
# __________________________________________________________________________________________________
# lambda_1786 (Lambda)            (None, 32, 32, 2)    0           conv2d_1890[0][0]
# __________________________________________________________________________________________________
# lambda_1787 (Lambda)            (None, 32, 32, 2)    0           conv2d_1890[0][0]
# __________________________________________________________________________________________________
# lambda_1788 (Lambda)            (None, 32, 32, 2)    0           conv2d_1890[0][0]
# __________________________________________________________________________________________________
# lambda_1789 (Lambda)            (None, 32, 32, 2)    0           conv2d_1890[0][0]
# __________________________________________________________________________________________________
# lambda_1790 (Lambda)            (None, 32, 32, 2)    0           conv2d_1890[0][0]
# __________________________________________________________________________________________________
# lambda_1791 (Lambda)            (None, 32, 32, 2)    0           conv2d_1890[0][0]
# __________________________________________________________________________________________________
# lambda_1792 (Lambda)            (None, 32, 32, 2)    0           conv2d_1890[0][0]
# __________________________________________________________________________________________________
# conv2d_1891 (Conv2D)            (None, 32, 32, 2)    38          lambda_1761[0][0]
# __________________________________________________________________________________________________
# conv2d_1892 (Conv2D)            (None, 32, 32, 2)    38          lambda_1762[0][0]
# __________________________________________________________________________________________________
# conv2d_1893 (Conv2D)            (None, 32, 32, 2)    38          lambda_1763[0][0]
# __________________________________________________________________________________________________
# conv2d_1894 (Conv2D)            (None, 32, 32, 2)    38          lambda_1764[0][0]
# __________________________________________________________________________________________________
# conv2d_1895 (Conv2D)            (None, 32, 32, 2)    38          lambda_1765[0][0]
# __________________________________________________________________________________________________
# conv2d_1896 (Conv2D)            (None, 32, 32, 2)    38          lambda_1766[0][0]
# __________________________________________________________________________________________________
# conv2d_1897 (Conv2D)            (None, 32, 32, 2)    38          lambda_1767[0][0]
# __________________________________________________________________________________________________
# conv2d_1898 (Conv2D)            (None, 32, 32, 2)    38          lambda_1768[0][0]
# __________________________________________________________________________________________________
# conv2d_1899 (Conv2D)            (None, 32, 32, 2)    38          lambda_1769[0][0]
# __________________________________________________________________________________________________
# conv2d_1900 (Conv2D)            (None, 32, 32, 2)    38          lambda_1770[0][0]
# __________________________________________________________________________________________________
# conv2d_1901 (Conv2D)            (None, 32, 32, 2)    38          lambda_1771[0][0]
# __________________________________________________________________________________________________
# conv2d_1902 (Conv2D)            (None, 32, 32, 2)    38          lambda_1772[0][0]
# __________________________________________________________________________________________________
# conv2d_1903 (Conv2D)            (None, 32, 32, 2)    38          lambda_1773[0][0]
# __________________________________________________________________________________________________
# conv2d_1904 (Conv2D)            (None, 32, 32, 2)    38          lambda_1774[0][0]
# __________________________________________________________________________________________________
# conv2d_1905 (Conv2D)            (None, 32, 32, 2)    38          lambda_1775[0][0]
# __________________________________________________________________________________________________
# conv2d_1906 (Conv2D)            (None, 32, 32, 2)    38          lambda_1776[0][0]
# __________________________________________________________________________________________________
# conv2d_1907 (Conv2D)            (None, 32, 32, 2)    38          lambda_1777[0][0]
# __________________________________________________________________________________________________
# conv2d_1908 (Conv2D)            (None, 32, 32, 2)    38          lambda_1778[0][0]
# __________________________________________________________________________________________________
# conv2d_1909 (Conv2D)            (None, 32, 32, 2)    38          lambda_1779[0][0]
# __________________________________________________________________________________________________
# conv2d_1910 (Conv2D)            (None, 32, 32, 2)    38          lambda_1780[0][0]
# __________________________________________________________________________________________________
# conv2d_1911 (Conv2D)            (None, 32, 32, 2)    38          lambda_1781[0][0]
# __________________________________________________________________________________________________
# conv2d_1912 (Conv2D)            (None, 32, 32, 2)    38          lambda_1782[0][0]
# __________________________________________________________________________________________________
# conv2d_1913 (Conv2D)            (None, 32, 32, 2)    38          lambda_1783[0][0]
# __________________________________________________________________________________________________
# conv2d_1914 (Conv2D)            (None, 32, 32, 2)    38          lambda_1784[0][0]
# __________________________________________________________________________________________________
# conv2d_1915 (Conv2D)            (None, 32, 32, 2)    38          lambda_1785[0][0]
# __________________________________________________________________________________________________
# conv2d_1916 (Conv2D)            (None, 32, 32, 2)    38          lambda_1786[0][0]
# __________________________________________________________________________________________________
# conv2d_1917 (Conv2D)            (None, 32, 32, 2)    38          lambda_1787[0][0]
# __________________________________________________________________________________________________
# conv2d_1918 (Conv2D)            (None, 32, 32, 2)    38          lambda_1788[0][0]
# __________________________________________________________________________________________________
# conv2d_1919 (Conv2D)            (None, 32, 32, 2)    38          lambda_1789[0][0]
# __________________________________________________________________________________________________
# conv2d_1920 (Conv2D)            (None, 32, 32, 2)    38          lambda_1790[0][0]
# __________________________________________________________________________________________________
# conv2d_1921 (Conv2D)            (None, 32, 32, 2)    38          lambda_1791[0][0]
# __________________________________________________________________________________________________
# conv2d_1922 (Conv2D)            (None, 32, 32, 2)    38          lambda_1792[0][0]
# __________________________________________________________________________________________________
# concatenate_56 (Concatenate)    (None, 32, 32, 64)   0           conv2d_1891[0][0]
#                                                                  conv2d_1892[0][0]
#                                                                  conv2d_1893[0][0]
#                                                                  conv2d_1894[0][0]
#                                                                  conv2d_1895[0][0]
#                                                                  conv2d_1896[0][0]
#                                                                  conv2d_1897[0][0]
#                                                                  conv2d_1898[0][0]
#                                                                  conv2d_1899[0][0]
#                                                                  conv2d_1900[0][0]
#                                                                  conv2d_1901[0][0]
#                                                                  conv2d_1902[0][0]
#                                                                  conv2d_1903[0][0]
#                                                                  conv2d_1904[0][0]
#                                                                  conv2d_1905[0][0]
#                                                                  conv2d_1906[0][0]
#                                                                  conv2d_1907[0][0]
#                                                                  conv2d_1908[0][0]
#                                                                  conv2d_1909[0][0]
#                                                                  conv2d_1910[0][0]
#                                                                  conv2d_1911[0][0]
#                                                                  conv2d_1912[0][0]
#                                                                  conv2d_1913[0][0]
#                                                                  conv2d_1914[0][0]
#                                                                  conv2d_1915[0][0]
#                                                                  conv2d_1916[0][0]
#                                                                  conv2d_1917[0][0]
#                                                                  conv2d_1918[0][0]
#                                                                  conv2d_1919[0][0]
#                                                                  conv2d_1920[0][0]
#                                                                  conv2d_1921[0][0]
#                                                                  conv2d_1922[0][0]
# __________________________________________________________________________________________________
# conv2d_1923 (Conv2D)            (None, 32, 32, 64)   4160        concatenate_56[0][0]
# __________________________________________________________________________________________________
# add_56 (Add)                    (None, 32, 32, 64)   0           conv2d_1923[0][0]
#                                                                  batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 32, 32, 64)   256         add_56[0][0]
# __________________________________________________________________________________________________
# conv2d_1924 (Conv2D)            (None, 32, 32, 64)   4160        batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# lambda_1793 (Lambda)            (None, 32, 32, 2)    0           conv2d_1924[0][0]
# __________________________________________________________________________________________________
# lambda_1794 (Lambda)            (None, 32, 32, 2)    0           conv2d_1924[0][0]
# __________________________________________________________________________________________________
# lambda_1795 (Lambda)            (None, 32, 32, 2)    0           conv2d_1924[0][0]
# __________________________________________________________________________________________________
# lambda_1796 (Lambda)            (None, 32, 32, 2)    0           conv2d_1924[0][0]
# __________________________________________________________________________________________________
# lambda_1797 (Lambda)            (None, 32, 32, 2)    0           conv2d_1924[0][0]
# __________________________________________________________________________________________________
# lambda_1798 (Lambda)            (None, 32, 32, 2)    0           conv2d_1924[0][0]
# __________________________________________________________________________________________________
# lambda_1799 (Lambda)            (None, 32, 32, 2)    0           conv2d_1924[0][0]
# __________________________________________________________________________________________________
# lambda_1800 (Lambda)            (None, 32, 32, 2)    0           conv2d_1924[0][0]
# __________________________________________________________________________________________________
# lambda_1801 (Lambda)            (None, 32, 32, 2)    0           conv2d_1924[0][0]
# __________________________________________________________________________________________________
# lambda_1802 (Lambda)            (None, 32, 32, 2)    0           conv2d_1924[0][0]
# __________________________________________________________________________________________________
# lambda_1803 (Lambda)            (None, 32, 32, 2)    0           conv2d_1924[0][0]
# __________________________________________________________________________________________________
# lambda_1804 (Lambda)            (None, 32, 32, 2)    0           conv2d_1924[0][0]
# __________________________________________________________________________________________________
# lambda_1805 (Lambda)            (None, 32, 32, 2)    0           conv2d_1924[0][0]
# __________________________________________________________________________________________________
# lambda_1806 (Lambda)            (None, 32, 32, 2)    0           conv2d_1924[0][0]
# __________________________________________________________________________________________________
# lambda_1807 (Lambda)            (None, 32, 32, 2)    0           conv2d_1924[0][0]
# __________________________________________________________________________________________________
# lambda_1808 (Lambda)            (None, 32, 32, 2)    0           conv2d_1924[0][0]
# __________________________________________________________________________________________________
# lambda_1809 (Lambda)            (None, 32, 32, 2)    0           conv2d_1924[0][0]
# __________________________________________________________________________________________________
# lambda_1810 (Lambda)            (None, 32, 32, 2)    0           conv2d_1924[0][0]
# __________________________________________________________________________________________________
# lambda_1811 (Lambda)            (None, 32, 32, 2)    0           conv2d_1924[0][0]
# __________________________________________________________________________________________________
# lambda_1812 (Lambda)            (None, 32, 32, 2)    0           conv2d_1924[0][0]
# __________________________________________________________________________________________________
# lambda_1813 (Lambda)            (None, 32, 32, 2)    0           conv2d_1924[0][0]
# __________________________________________________________________________________________________
# lambda_1814 (Lambda)            (None, 32, 32, 2)    0           conv2d_1924[0][0]
# __________________________________________________________________________________________________
# lambda_1815 (Lambda)            (None, 32, 32, 2)    0           conv2d_1924[0][0]
# __________________________________________________________________________________________________
# lambda_1816 (Lambda)            (None, 32, 32, 2)    0           conv2d_1924[0][0]
# __________________________________________________________________________________________________
# lambda_1817 (Lambda)            (None, 32, 32, 2)    0           conv2d_1924[0][0]
# __________________________________________________________________________________________________
# lambda_1818 (Lambda)            (None, 32, 32, 2)    0           conv2d_1924[0][0]
# __________________________________________________________________________________________________
# lambda_1819 (Lambda)            (None, 32, 32, 2)    0           conv2d_1924[0][0]
# __________________________________________________________________________________________________
# lambda_1820 (Lambda)            (None, 32, 32, 2)    0           conv2d_1924[0][0]
# __________________________________________________________________________________________________
# lambda_1821 (Lambda)            (None, 32, 32, 2)    0           conv2d_1924[0][0]
# __________________________________________________________________________________________________
# lambda_1822 (Lambda)            (None, 32, 32, 2)    0           conv2d_1924[0][0]
# __________________________________________________________________________________________________
# lambda_1823 (Lambda)            (None, 32, 32, 2)    0           conv2d_1924[0][0]
# __________________________________________________________________________________________________
# lambda_1824 (Lambda)            (None, 32, 32, 2)    0           conv2d_1924[0][0]
# __________________________________________________________________________________________________
# conv2d_1925 (Conv2D)            (None, 32, 32, 2)    38          lambda_1793[0][0]
# __________________________________________________________________________________________________
# conv2d_1926 (Conv2D)            (None, 32, 32, 2)    38          lambda_1794[0][0]
# __________________________________________________________________________________________________
# conv2d_1927 (Conv2D)            (None, 32, 32, 2)    38          lambda_1795[0][0]
# __________________________________________________________________________________________________
# conv2d_1928 (Conv2D)            (None, 32, 32, 2)    38          lambda_1796[0][0]
# __________________________________________________________________________________________________
# conv2d_1929 (Conv2D)            (None, 32, 32, 2)    38          lambda_1797[0][0]
# __________________________________________________________________________________________________
# conv2d_1930 (Conv2D)            (None, 32, 32, 2)    38          lambda_1798[0][0]
# __________________________________________________________________________________________________
# conv2d_1931 (Conv2D)            (None, 32, 32, 2)    38          lambda_1799[0][0]
# __________________________________________________________________________________________________
# conv2d_1932 (Conv2D)            (None, 32, 32, 2)    38          lambda_1800[0][0]
# __________________________________________________________________________________________________
# conv2d_1933 (Conv2D)            (None, 32, 32, 2)    38          lambda_1801[0][0]
# __________________________________________________________________________________________________
# conv2d_1934 (Conv2D)            (None, 32, 32, 2)    38          lambda_1802[0][0]
# __________________________________________________________________________________________________
# conv2d_1935 (Conv2D)            (None, 32, 32, 2)    38          lambda_1803[0][0]
# __________________________________________________________________________________________________
# conv2d_1936 (Conv2D)            (None, 32, 32, 2)    38          lambda_1804[0][0]
# __________________________________________________________________________________________________
# conv2d_1937 (Conv2D)            (None, 32, 32, 2)    38          lambda_1805[0][0]
# __________________________________________________________________________________________________
# conv2d_1938 (Conv2D)            (None, 32, 32, 2)    38          lambda_1806[0][0]
# __________________________________________________________________________________________________
# conv2d_1939 (Conv2D)            (None, 32, 32, 2)    38          lambda_1807[0][0]
# __________________________________________________________________________________________________
# conv2d_1940 (Conv2D)            (None, 32, 32, 2)    38          lambda_1808[0][0]
# __________________________________________________________________________________________________
# conv2d_1941 (Conv2D)            (None, 32, 32, 2)    38          lambda_1809[0][0]
# __________________________________________________________________________________________________
# conv2d_1942 (Conv2D)            (None, 32, 32, 2)    38          lambda_1810[0][0]
# __________________________________________________________________________________________________
# conv2d_1943 (Conv2D)            (None, 32, 32, 2)    38          lambda_1811[0][0]
# __________________________________________________________________________________________________
# conv2d_1944 (Conv2D)            (None, 32, 32, 2)    38          lambda_1812[0][0]
# __________________________________________________________________________________________________
# conv2d_1945 (Conv2D)            (None, 32, 32, 2)    38          lambda_1813[0][0]
# __________________________________________________________________________________________________
# conv2d_1946 (Conv2D)            (None, 32, 32, 2)    38          lambda_1814[0][0]
# __________________________________________________________________________________________________
# conv2d_1947 (Conv2D)            (None, 32, 32, 2)    38          lambda_1815[0][0]
# __________________________________________________________________________________________________
# conv2d_1948 (Conv2D)            (None, 32, 32, 2)    38          lambda_1816[0][0]
# __________________________________________________________________________________________________
# conv2d_1949 (Conv2D)            (None, 32, 32, 2)    38          lambda_1817[0][0]
# __________________________________________________________________________________________________
# conv2d_1950 (Conv2D)            (None, 32, 32, 2)    38          lambda_1818[0][0]
# __________________________________________________________________________________________________
# conv2d_1951 (Conv2D)            (None, 32, 32, 2)    38          lambda_1819[0][0]
# __________________________________________________________________________________________________
# conv2d_1952 (Conv2D)            (None, 32, 32, 2)    38          lambda_1820[0][0]
# __________________________________________________________________________________________________
# conv2d_1953 (Conv2D)            (None, 32, 32, 2)    38          lambda_1821[0][0]
# __________________________________________________________________________________________________
# conv2d_1954 (Conv2D)            (None, 32, 32, 2)    38          lambda_1822[0][0]
# __________________________________________________________________________________________________
# conv2d_1955 (Conv2D)            (None, 32, 32, 2)    38          lambda_1823[0][0]
# __________________________________________________________________________________________________
# conv2d_1956 (Conv2D)            (None, 32, 32, 2)    38          lambda_1824[0][0]
# __________________________________________________________________________________________________
# concatenate_57 (Concatenate)    (None, 32, 32, 64)   0           conv2d_1925[0][0]
#                                                                  conv2d_1926[0][0]
#                                                                  conv2d_1927[0][0]
# ...
# __________________________________________________________________________________________________
# lambda_1992 (Lambda)            (None, 7, 7, 2)      0           conv2d_2130[0][0]
# __________________________________________________________________________________________________
# lambda_1993 (Lambda)            (None, 7, 7, 2)      0           conv2d_2130[0][0]
# __________________________________________________________________________________________________
# lambda_1994 (Lambda)            (None, 7, 7, 2)      0           conv2d_2130[0][0]
# __________________________________________________________________________________________________
# lambda_1995 (Lambda)            (None, 7, 7, 2)      0           conv2d_2130[0][0]
# __________________________________________________________________________________________________
# lambda_1996 (Lambda)            (None, 7, 7, 2)      0           conv2d_2130[0][0]
# __________________________________________________________________________________________________
# lambda_1997 (Lambda)            (None, 7, 7, 2)      0           conv2d_2130[0][0]
# __________________________________________________________________________________________________
# lambda_1998 (Lambda)            (None, 7, 7, 2)      0           conv2d_2130[0][0]
# __________________________________________________________________________________________________
# lambda_1999 (Lambda)            (None, 7, 7, 2)      0           conv2d_2130[0][0]
# __________________________________________________________________________________________________
# lambda_2000 (Lambda)            (None, 7, 7, 2)      0           conv2d_2130[0][0]
# __________________________________________________________________________________________________
# lambda_2001 (Lambda)            (None, 7, 7, 2)      0           conv2d_2130[0][0]
# __________________________________________________________________________________________________
# lambda_2002 (Lambda)            (None, 7, 7, 2)      0           conv2d_2130[0][0]
# __________________________________________________________________________________________________
# lambda_2003 (Lambda)            (None, 7, 7, 2)      0           conv2d_2130[0][0]
# __________________________________________________________________________________________________
# lambda_2004 (Lambda)            (None, 7, 7, 2)      0           conv2d_2130[0][0]
# __________________________________________________________________________________________________
# lambda_2005 (Lambda)            (None, 7, 7, 2)      0           conv2d_2130[0][0]
# __________________________________________________________________________________________________
# lambda_2006 (Lambda)            (None, 7, 7, 2)      0           conv2d_2130[0][0]
# __________________________________________________________________________________________________
# lambda_2007 (Lambda)            (None, 7, 7, 2)      0           conv2d_2130[0][0]
# __________________________________________________________________________________________________
# lambda_2008 (Lambda)            (None, 7, 7, 2)      0           conv2d_2130[0][0]
# __________________________________________________________________________________________________
# lambda_2009 (Lambda)            (None, 7, 7, 2)      0           conv2d_2130[0][0]
# __________________________________________________________________________________________________
# lambda_2010 (Lambda)            (None, 7, 7, 2)      0           conv2d_2130[0][0]
# __________________________________________________________________________________________________
# lambda_2011 (Lambda)            (None, 7, 7, 2)      0           conv2d_2130[0][0]
# __________________________________________________________________________________________________
# lambda_2012 (Lambda)            (None, 7, 7, 2)      0           conv2d_2130[0][0]
# __________________________________________________________________________________________________
# lambda_2013 (Lambda)            (None, 7, 7, 2)      0           conv2d_2130[0][0]
# __________________________________________________________________________________________________
# lambda_2014 (Lambda)            (None, 7, 7, 2)      0           conv2d_2130[0][0]
# __________________________________________________________________________________________________
# lambda_2015 (Lambda)            (None, 7, 7, 2)      0           conv2d_2130[0][0]
# __________________________________________________________________________________________________
# lambda_2016 (Lambda)            (None, 7, 7, 2)      0           conv2d_2130[0][0]
# __________________________________________________________________________________________________
# conv2d_2131 (Conv2D)            (None, 7, 7, 2)      38          lambda_1985[0][0]
# __________________________________________________________________________________________________
# conv2d_2132 (Conv2D)            (None, 7, 7, 2)      38          lambda_1986[0][0]
# __________________________________________________________________________________________________
# conv2d_2133 (Conv2D)            (None, 7, 7, 2)      38          lambda_1987[0][0]
# __________________________________________________________________________________________________
# conv2d_2134 (Conv2D)            (None, 7, 7, 2)      38          lambda_1988[0][0]
# __________________________________________________________________________________________________
# conv2d_2135 (Conv2D)            (None, 7, 7, 2)      38          lambda_1989[0][0]
# __________________________________________________________________________________________________
# conv2d_2136 (Conv2D)            (None, 7, 7, 2)      38          lambda_1990[0][0]
# __________________________________________________________________________________________________
# conv2d_2137 (Conv2D)            (None, 7, 7, 2)      38          lambda_1991[0][0]
# __________________________________________________________________________________________________
# conv2d_2138 (Conv2D)            (None, 7, 7, 2)      38          lambda_1992[0][0]
# __________________________________________________________________________________________________
# conv2d_2139 (Conv2D)            (None, 7, 7, 2)      38          lambda_1993[0][0]
# __________________________________________________________________________________________________
# conv2d_2140 (Conv2D)            (None, 7, 7, 2)      38          lambda_1994[0][0]
# __________________________________________________________________________________________________
# conv2d_2141 (Conv2D)            (None, 7, 7, 2)      38          lambda_1995[0][0]
# __________________________________________________________________________________________________
# conv2d_2142 (Conv2D)            (None, 7, 7, 2)      38          lambda_1996[0][0]
# __________________________________________________________________________________________________
# conv2d_2143 (Conv2D)            (None, 7, 7, 2)      38          lambda_1997[0][0]
# __________________________________________________________________________________________________
# conv2d_2144 (Conv2D)            (None, 7, 7, 2)      38          lambda_1998[0][0]
# __________________________________________________________________________________________________
# conv2d_2145 (Conv2D)            (None, 7, 7, 2)      38          lambda_1999[0][0]
# __________________________________________________________________________________________________
# conv2d_2146 (Conv2D)            (None, 7, 7, 2)      38          lambda_2000[0][0]
# __________________________________________________________________________________________________
# conv2d_2147 (Conv2D)            (None, 7, 7, 2)      38          lambda_2001[0][0]
# __________________________________________________________________________________________________
# conv2d_2148 (Conv2D)            (None, 7, 7, 2)      38          lambda_2002[0][0]
# __________________________________________________________________________________________________
# conv2d_2149 (Conv2D)            (None, 7, 7, 2)      38          lambda_2003[0][0]
# __________________________________________________________________________________________________
# conv2d_2150 (Conv2D)            (None, 7, 7, 2)      38          lambda_2004[0][0]
# __________________________________________________________________________________________________
# conv2d_2151 (Conv2D)            (None, 7, 7, 2)      38          lambda_2005[0][0]
# __________________________________________________________________________________________________
# conv2d_2152 (Conv2D)            (None, 7, 7, 2)      38          lambda_2006[0][0]
# __________________________________________________________________________________________________
# conv2d_2153 (Conv2D)            (None, 7, 7, 2)      38          lambda_2007[0][0]
# __________________________________________________________________________________________________
# conv2d_2154 (Conv2D)            (None, 7, 7, 2)      38          lambda_2008[0][0]
# __________________________________________________________________________________________________
# conv2d_2155 (Conv2D)            (None, 7, 7, 2)      38          lambda_2009[0][0]
# __________________________________________________________________________________________________
# conv2d_2156 (Conv2D)            (None, 7, 7, 2)      38          lambda_2010[0][0]
# __________________________________________________________________________________________________
# conv2d_2157 (Conv2D)            (None, 7, 7, 2)      38          lambda_2011[0][0]
# __________________________________________________________________________________________________
# conv2d_2158 (Conv2D)            (None, 7, 7, 2)      38          lambda_2012[0][0]
# __________________________________________________________________________________________________
# conv2d_2159 (Conv2D)            (None, 7, 7, 2)      38          lambda_2013[0][0]
# __________________________________________________________________________________________________
# conv2d_2160 (Conv2D)            (None, 7, 7, 2)      38          lambda_2014[0][0]
# __________________________________________________________________________________________________
# conv2d_2161 (Conv2D)            (None, 7, 7, 2)      38          lambda_2015[0][0]
# __________________________________________________________________________________________________
# conv2d_2162 (Conv2D)            (None, 7, 7, 2)      38          lambda_2016[0][0]
# __________________________________________________________________________________________________
# concatenate_63 (Concatenate)    (None, 7, 7, 64)     0           conv2d_2131[0][0]
#                                                                  conv2d_2132[0][0]
#                                                                  conv2d_2133[0][0]
#                                                                  conv2d_2134[0][0]
#                                                                  conv2d_2135[0][0]
#                                                                  conv2d_2136[0][0]
#                                                                  conv2d_2137[0][0]
#                                                                  conv2d_2138[0][0]
#                                                                  conv2d_2139[0][0]
#                                                                  conv2d_2140[0][0]
#                                                                  conv2d_2141[0][0]
#                                                                  conv2d_2142[0][0]
#                                                                  conv2d_2143[0][0]
#                                                                  conv2d_2144[0][0]
#                                                                  conv2d_2145[0][0]
#                                                                  conv2d_2146[0][0]
#                                                                  conv2d_2147[0][0]
#                                                                  conv2d_2148[0][0]
#                                                                  conv2d_2149[0][0]
#                                                                  conv2d_2150[0][0]
#                                                                  conv2d_2151[0][0]
#                                                                  conv2d_2152[0][0]
#                                                                  conv2d_2153[0][0]
#                                                                  conv2d_2154[0][0]
#                                                                  conv2d_2155[0][0]
#                                                                  conv2d_2156[0][0]
#                                                                  conv2d_2157[0][0]
#                                                                  conv2d_2158[0][0]
#                                                                  conv2d_2159[0][0]
#                                                                  conv2d_2160[0][0]
#                                                                  conv2d_2161[0][0]
#                                                                  conv2d_2162[0][0]
# __________________________________________________________________________________________________
# conv2d_2163 (Conv2D)            (None, 7, 7, 256)    16640       concatenate_63[0][0]
# __________________________________________________________________________________________________
# add_63 (Add)                    (None, 7, 7, 256)    0           conv2d_2163[0][0]
#                                                                  batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, 7, 7, 256)    1024        add_63[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_7 (Glo (None, 256)          0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# fc2 (Dense)                     (None, 25)           6425        global_average_pooling2d_7[0][0]
# ==================================================================================================
# Total params: 566,617
# Trainable params: 563,801
# Non-trainable params: 2,816
# __________________________________________________________________________________________________
# None
# residual_network

# %%
import experiment
batch_size = 32
epochs=10
rotated_epochs=epochs*2
scores=experiment.train_rotated(model,rotated_model,x_train,y_train,x_test,
                          y_test,num_classes,input_shape,batch_size,epochs,rotated_epochs)
# Out:
# Training model with unrotated dataset...
# Epoch 1/10
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# ~/.python/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1322     try:
# -> 1323       return fn(*args)
#    1324     except errors.OpError as e:
#
# ~/.python/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1301                                    feed_dict, fetch_list, target_list,
# -> 1302                                    status, run_metadata)
#    1303
#
# ~/.python/lib/python3.6/site-packages/tensorflow/python/framework/errors_impl.py in __exit__(self, type_arg, value_arg, traceback_arg)
#     472             compat.as_text(c_api.TF_Message(self.status.status)),
# --> 473             c_api.TF_GetCode(self.status.status))
#     474     # Delete the underlying status object from memory otherwise it stays alive
#
# ResourceExhaustedError: OOM when allocating tensor of shape [3,3,128,256] and type float
# 	 [[Node: training_2/RMSprop/zeros_426 = Const[dtype=DT_FLOAT, value=Tensor<type: float shape: [3,3,128,256] values: [[[0 0 0]]]...>, _device="/job:localhost/replica:0/task:0/device:GPU:0"]()]]
#
# During handling of the above exception, another exception occurred:
#
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-14-236006e39fd5> in <module>()
#       4 rotated_epochs=epochs*2
#       5 scores=experiment.train_rotated(model,rotated_model,x_train,y_train,x_test,
# ----> 6                           y_test,num_classes,input_shape,batch_size,epochs,rotated_epochs)
#
# ~/dev/exp/rotation/experiment.py in train_rotated(model, rotated_model, x_train, y_train, x_test, y_test, classes, input_shape, batch_size, epochs, rotated_epochs, plot_accuracy)
#      25               epochs=epochs,
#      26               verbose=1,
# ---> 27               validation_data=test_dataset)
#      28         callback_list = get_callbacks(no_improv_epochs=max(epochs//4,3))
#      29         if plot_accuracy:
#
# ~/.python/lib/python3.6/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name +
#      90                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~/.python/lib/python3.6/site-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2175                     outs = self.train_on_batch(x, y,
#    2176                                                sample_weight=sample_weight,
# -> 2177                                                class_weight=class_weight)
#    2178
#    2179                     if not isinstance(outs, list):
#
# ~/.python/lib/python3.6/site-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1847             ins = x + y + sample_weights
#    1848         self._make_train_function()
# -> 1849         outputs = self.train_function(ins)
#    1850         if len(outputs) == 1:
#    1851             return outputs[0]
#
# ~/.python/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2471             feed_dict[tensor] = value
#    2472         fetches = self.outputs + [self.updates_op] + self.fetches
# -> 2473         session = get_session()
#    2474         updated = session.run(fetches=fetches, feed_dict=feed_dict,
#    2475                               **self.session_kwargs)
#
# ~/.python/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in get_session()
#     194                     v._keras_initialized = True
#     195                 if uninitialized_vars:
# --> 196                     session.run(tf.variables_initializer(uninitialized_vars))
#     197     # hack for list_devices() function.
#     198     # list_devices() function is not available under tensorflow r1.3.
#
# ~/.python/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     887     try:
#     888       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 889                          run_metadata_ptr)
#     890       if run_metadata:
#     891         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/.python/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1118     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1119       results = self._do_run(handle, final_targets, final_fetches,
# -> 1120                              feed_dict_tensor, options, run_metadata)
#    1121     else:
#    1122       results = []
#
# ~/.python/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1315     if handle is None:
#    1316       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1317                            options, run_metadata)
#    1318     else:
#    1319       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# ~/.python/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1334         except KeyError:
#    1335           pass
# -> 1336       raise type(e)(node_def, op, message)
#    1337
#    1338   def _extend_graph(self):
#
# ResourceExhaustedError: OOM when allocating tensor of shape [3,3,128,256] and type float
# 	 [[Node: training_2/RMSprop/zeros_426 = Const[dtype=DT_FLOAT, value=Tensor<type: float shape: [3,3,128,256] values: [[[0 0 0]]]...>, _device="/job:localhost/replica:0/task:0/device:GPU:0"]()]]
#
# Caused by op 'training_2/RMSprop/zeros_426', defined at:
#   File "/home/facundo/.python/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/home/facundo/.python/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/facundo/.python/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/facundo/.python/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/facundo/.python/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 486, in start
#     self.io_loop.start()
#   File "/home/facundo/.python/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 127, in start
#     self.asyncio_loop.run_forever()
#   File "/home/facundo/.python/lib/python3.6/asyncio/base_events.py", line 421, in run_forever
#     self._run_once()
#   File "/home/facundo/.python/lib/python3.6/asyncio/base_events.py", line 1425, in _run_once
#     handle._run()
#   File "/home/facundo/.python/lib/python3.6/asyncio/events.py", line 127, in _run
#     self._callback(*self._args)
#   File "/home/facundo/.python/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 117, in _handle_events
#     handler_func(fileobj, events)
#   File "/home/facundo/.python/lib/python3.6/site-packages/tornado/stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/facundo/.python/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/home/facundo/.python/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/home/facundo/.python/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/home/facundo/.python/lib/python3.6/site-packages/tornado/stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/facundo/.python/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/home/facundo/.python/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/home/facundo/.python/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/home/facundo/.python/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/facundo/.python/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/facundo/.python/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2698, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/facundo/.python/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2802, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/home/facundo/.python/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-14-236006e39fd5>", line 6, in <module>
#     y_test,num_classes,input_shape,batch_size,epochs,rotated_epochs)
#   File "/home/facundo/dev/exp/rotation/experiment.py", line 27, in train_rotated
#     validation_data=test_dataset)
#   File "/home/facundo/.python/lib/python3.6/site-packages/keras/legacy/interfaces.py", line 91, in wrapper
#     return func(*args, **kwargs)
#   File "/home/facundo/.python/lib/python3.6/site-packages/keras/engine/training.py", line 2026, in fit_generator
#     self._make_train_function()
#   File "/home/facundo/.python/lib/python3.6/site-packages/keras/engine/training.py", line 970, in _make_train_function
#     loss=self.total_loss)
#   File "/home/facundo/.python/lib/python3.6/site-packages/keras/legacy/interfaces.py", line 91, in wrapper
#     return func(*args, **kwargs)
#   File "/home/facundo/.python/lib/python3.6/site-packages/keras/optimizers.py", line 234, in get_updates
#     accumulators = [K.zeros(K.int_shape(p), dtype=K.dtype(p)) for p in params]
#   File "/home/facundo/.python/lib/python3.6/site-packages/keras/optimizers.py", line 234, in <listcomp>
#     accumulators = [K.zeros(K.int_shape(p), dtype=K.dtype(p)) for p in params]
#   File "/home/facundo/.python/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py", line 689, in zeros
#     v = tf.zeros(shape=shape, dtype=tf_dtype, name=name)
#   File "/home/facundo/.python/lib/python3.6/site-packages/tensorflow/python/ops/array_ops.py", line 1439, in zeros
#     output = constant(zero, shape=shape, dtype=dtype, name=name)
#   File "/home/facundo/.python/lib/python3.6/site-packages/tensorflow/python/framework/constant_op.py", line 214, in constant
#     name=name).outputs[0]
#   File "/home/facundo/.python/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 2956, in create_op
#     op_def=op_def)
#   File "/home/facundo/.python/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 1470, in __init__
#     self._traceback = self._graph._extract_stack()  # pylint: disable=protected-access
#
# ResourceExhaustedError (see above for traceback): OOM when allocating tensor of shape [3,3,128,256] and type float
# 	 [[Node: training_2/RMSprop/zeros_426 = Const[dtype=DT_FLOAT, value=Tensor<type: float shape: [3,3,128,256] values: [[[0 0 0]]]...>, _device="/job:localhost/replica:0/task:0/device:GPU:0"]()]]

# %%
from datetime import datetime

output_file="results_resnet_b.txt"
f= open(output_file,"a+")
general_message="%s\nResults on dataset %s with model %s and rotated model %s\n" % (str(datetime.now()),dataset,model.name,rotated_model.name)
f.write(general_message)
print(general_message)
for k,v in scores.items():
    message='%s score: loss=%f, accuracy=%f\n' % (k,v[0],v[1])
    print(message)
    f.write(message)
f.write("\n\n")    
f.close()
# Out:
# 2018-02-28 20:50:50.042450
# Results on dataset cifar10 with model residual_network and rotated model residual_network
#
# rotated_model_test_dataset score: loss=0.663084, accuracy=0.770700
#
# model_test_dataset score: loss=0.570121, accuracy=0.841000
#
# rotated_model_rotated_test_dataset score: loss=0.723364, accuracy=0.750500
#
# model_rotated_test_dataset score: loss=4.929166, accuracy=0.279200
